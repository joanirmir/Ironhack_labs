# %% [markdown]
# ## Analyis_Case_Study

# %% [markdown]
# Import libraries and concatinate the csv_files first

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Rename the columsn 'State' and 'Gender' in file3 and merge the files together

# %%
file3_df = pd.read_csv('data/file3.csv')

# %%
def rename_columns(file3_df):
    file3_df.rename(columns ={'State':'ST', 'Gender':'GENDER'}, inplace = True)
    return file3_df

# %%
rename_columns(file3_df)
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
def concatinate_data_files():
    file1 = pd.read_csv('data/file1.csv')
    file2 = pd.read_csv('data/file2.csv')
    file3 = file3_df
    return pd.concat([file1,file2,file3], axis=0)

# %%
insurance_df = concatinate_data_files()

# %%
insurance_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# #### Standarizing header names

# %% [markdown]
# First lower case column names:

# %%
def lower_case_column_names(insurance_df):
    insurance_df.columns=[i. lower() for i in insurance_df.columns]
    return insurance_df

# %%
insurance_df = lower_case_column_names(insurance_df)

# %%
insurance_df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# #### Rename columns

# %%
def rename_columns(insurance_df):
    insurance_df.rename(columns = {'st':'state'}, inplace = True)
    return insurance_df

# %%
insurance_df = rename_columns(insurance_df)

# %%
insurance_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# #### Deleting and rearranging columns

# %% [markdown]
# Deleting the column customer:

# %%
def drop_columns(insurance_df):
    insurance_df.drop(columns=['customer'], inplace=True)
    return insurance_df

# %%
insurance_df = drop_columns(insurance_df)

# %%
insurance_df
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %% [markdown]
# Rearranging columns:

# %%
list(insurance_df.columns)
# Out:
# ['state',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
insurance_df = insurance_df[[
    'state',
    'gender',
    'education',
    'income',
    'customer lifetime value',
    'vehicle class',
    'monthly premium auto',
    'policy type',
    'number of open complaints',
    'total claim amount']]

# %%
insurance_df.head()
# Out:
#         state gender             education   income customer lifetime value  \
# 0  Washington    NaN                Master      0.0                     NaN
# 1     Arizona      F              Bachelor      0.0              697953.59%
# 2      Nevada      F              Bachelor  48767.0             1288743.17%
# 3  California      M              Bachelor      0.0              764586.18%
# 4  Washington      M  High School or Below  36357.0              536307.65%
#
#    vehicle class  monthly premium auto     policy type  \
# 0  Four-Door Car                1000.0   Personal Auto
# 1  Four-Door Car                  94.0   Personal Auto
# 2   Two-Door Car                 108.0   Personal Auto
# 3            SUV                 106.0  Corporate Auto
# 4  Four-Door Car                  68.0   Personal Auto
#
#   number of open complaints  total claim amount
# 0                    1/0/00            2.704934
# 1                    1/0/00         1131.464935
# ...

# %% [markdown]
# #### Check the data type

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   income                     9137 non-null   float64
#  4   customer lifetime value    9130 non-null   object
#  5   vehicle class              9137 non-null   object
#  6   monthly premium auto       9137 non-null   float64
#  7   policy type                9137 non-null   object
#  8   number of open complaints  9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %% [markdown]
# The columns 'customer lifetime value' and 'number of open complaints' have as data type object.

# %% [markdown]
# We need to convert them to the data type float:

# %%
insurance_df['customer lifetime value'].unique().tolist()
# Out:
# [nan,
#  '697953.59%',
#  '1288743.17%',
#  '764586.18%',
#  '536307.65%',
#  '825629.78%',
#  '538089.86%',
#  '721610.03%',
#  '2412750.40%',
#  '738817.81%',
#  '473899.20%',
#  '819719.71%',
#  '879879.70%',
#  '881901.89%',
#  '538443.17%',
#  '746313.94%',
#  '256686.78%',
#  '394524.16%',
#  '571033.31%',
#  '816261.71%',
#  '287205.13%',
#  '617710.93%',
#  '245019.10%',
#  '239210.79%',
#  '580206.60%',
#  '394637.21%',
#  '916206.32%',
#  '1290256.01%',
#  '323536.05%',
#  '245458.35%',
#  '1897545.61%',
#  '471532.13%',
#  '473787.17%',
#  '493291.63%',
#  '574422.97%',
#  '1389173.57%',
#  '738097.67%',
#  '309003.41%',
#  '252163.31%',
#  '265206.18%',
#  '277104.50%',
#  '393900.64%',
#  '1223187.97%',
#  '495165.61%',
#  '1281910.29%',
#  '446851.05%',
#  '551434.40%',
#  '334387.53%',
#  '229447.89%',
#  '3670742.64%',
#  '3347334.95%',
#  '798343.17%',
#  '487938.48%',
#  '429399.73%',
#  '716439.55%',
#  '761951.58%',
#  '395800.28%',
#  '449949.33%',
# ...

# %%
insurance_df['customer lifetime value'] = pd.to_numeric(insurance_df['customer lifetime value'], errors ='coerce')

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   income                     9137 non-null   float64
#  4   customer lifetime value    7070 non-null   float64
#  5   vehicle class              9137 non-null   object
#  6   monthly premium auto       9137 non-null   float64
#  7   policy type                9137 non-null   object
#  8   number of open complaints  9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# For the column 'number of open complaints':

# %%
insurance_df['number of open complaints'] = pd.to_numeric(insurance_df['customer lifetime value'], errors = 'coerce')

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   income                     9137 non-null   float64
#  4   customer lifetime value    7070 non-null   float64
#  5   vehicle class              9137 non-null   object
#  6   monthly premium auto       9137 non-null   float64
#  7   policy type                9137 non-null   object
#  8   number of open complaints  7070 non-null   float64
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 1.0+ MB

# %% [markdown]
# #### Filtering data and correcting typos

# %%
insurance_df['gender'].unique().tolist()
# Out:
# [nan, 'F', 'M', 'Femal', 'Male', 'female']

# %%
insurance_df['gender'].replace({'Male':'M', 'Female':'F', 'female':'F', 'Femal':'F'}, inplace=True)

# %%
insurance_df['gender'].unique().tolist()
# Out:
# [nan, 'F', 'M']

# %% [markdown]
# For the column 'state':

# %%
insurance_df['state'].unique().tolist()
# Out:
# ['Washington',
#  'Arizona',
#  'Nevada',
#  'California',
#  'Oregon',
#  'Cali',
#  'AZ',
#  'WA',
#  nan]

# %%
insurance_df['state'].replace({'WA':'Washington', 'AZ': 'Arizona', 'Cali':'California'}, inplace=True)

# %%
insurance_df['state'].unique().tolist()
# Out:
# ['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan]

# %% [markdown]
# #### Removing duplicates

# %%
insurance_df.drop_duplicates()
# Out:
#            state gender             education   income  \
# 0     Washington    NaN                Master      0.0
# 1        Arizona      F              Bachelor      0.0
# 2         Nevada      F              Bachelor  48767.0
# 3     California      M              Bachelor      0.0
# 4     Washington      M  High School or Below  36357.0
# ...          ...    ...                   ...      ...
# 7065  California      M              Bachelor  71941.0
# 7066  California      F               College  21604.0
# 7067  California      M              Bachelor      0.0
# 7068  California      M               College  21941.0
# 7069  California      M               College      0.0
#
#       customer lifetime value  vehicle class  monthly premium auto  \
# 0                         NaN  Four-Door Car                1000.0
# 1                         NaN  Four-Door Car                  94.0
# 2                         NaN   Two-Door Car                 108.0
# ...

# %% [markdown]
# #### Replacing null values

# %% [markdown]
# Replace missing values with means of the column (for numerical columns):

# %%
insurance_df.describe().transpose()
# Out:
#                             count          mean           std          min  \
# income                     9137.0  37828.820291  30358.716159     0.000000
# customer lifetime value    7070.0   8028.803803   6942.419253  1898.007675
# monthly premium auto       9137.0    110.391266    581.376032    61.000000
# number of open complaints  7070.0   8028.803803   6942.419253  1898.007675
# total claim amount         9137.0    430.527140    289.582968     0.099007
#
#                                    25%           50%           75%  \
# income                        0.000000  34244.000000  62447.000000
# customer lifetime value    3981.073024   5782.095838   8989.995803
# monthly premium auto         68.000000     83.000000    109.000000
# number of open complaints  3981.073024   5782.095838   8989.995803
# total claim amount          266.996814    377.561463    546.420009
#
#                                     max
# income                     99981.000000
# ...

# %%
insurance_df['customer lifetime value'].unique().tolist()
# Out:
# [nan,
#  3479.137523,
#  2502.637401,
#  3265.156348,
#  4455.843406,
#  7704.95848,
#  2750.705045,
#  13024.13012,
#  2538.62632,
#  2585.955652,
#  5096.673223,
#  10083.48688,
#  4943.386117,
#  6516.214888,
#  8838.085637,
#  3810.238281,
#  6334.466403,
#  11665.09779,
#  10972.06778,
#  6006.963446,
#  2656.713092,
#  2359.423599,
#  12036.62051,
#  8467.387317,
#  9392.557553,
#  5227.230377,
#  2693.75925,
#  2227.072755,
#  2326.864833,
#  16794.31422,
#  5016.827946,
#  7757.924239,
#  8609.158215,
#  5275.056933,
#  5746.32619,
#  2705.987629,
#  6186.265217,
#  22445.28088,
#  6277.844624,
#  7215.821106,
#  6514.430592,
#  34708.87261,
#  4216.19522,
#  13158.37206,
#  2917.539465,
#  6355.678846,
#  13269.59942,
#  5880.256499,
#  5926.729379,
#  4121.252137,
#  7956.152761,
#  24127.50402,
#  26864.20332,
#  31934.62164,
#  5132.684537,
#  4759.624343,
#  2637.942355,
#  6503.397049,
#  12786.66898,
#  3147.973444,
#  5618.485357,
#  3230.576665,
#  7434.675149,
# ...

# %%
#insurance_df['customer lifetime value'].replace({'nan':'8028.803803'}, inplace=True)

# %%
insurance_df['customer lifetime value'].unique().tolist()
# Out:
# [nan,
#  3479.137523,
#  2502.637401,
#  3265.156348,
#  4455.843406,
#  7704.95848,
#  2750.705045,
#  13024.13012,
#  2538.62632,
#  2585.955652,
#  5096.673223,
#  10083.48688,
#  4943.386117,
#  6516.214888,
#  8838.085637,
#  3810.238281,
#  6334.466403,
#  11665.09779,
#  10972.06778,
#  6006.963446,
#  2656.713092,
#  2359.423599,
#  12036.62051,
#  8467.387317,
#  9392.557553,
#  5227.230377,
#  2693.75925,
#  2227.072755,
#  2326.864833,
#  16794.31422,
#  5016.827946,
#  7757.924239,
#  8609.158215,
#  5275.056933,
#  5746.32619,
#  2705.987629,
#  6186.265217,
#  22445.28088,
#  6277.844624,
#  7215.821106,
#  6514.430592,
#  34708.87261,
#  4216.19522,
#  13158.37206,
#  2917.539465,
#  6355.678846,
#  13269.59942,
#  5880.256499,
#  5926.729379,
#  4121.252137,
#  7956.152761,
#  24127.50402,
#  26864.20332,
#  31934.62164,
#  5132.684537,
#  4759.624343,
#  2637.942355,
#  6503.397049,
#  12786.66898,
#  3147.973444,
#  5618.485357,
#  3230.576665,
#  7434.675149,
# ...

# %%
insurance_df['number of open complaints'].unique().tolist()
# Out:
# [nan,
#  3479.137523,
#  2502.637401,
#  3265.156348,
#  4455.843406,
#  7704.95848,
#  2750.705045,
#  13024.13012,
#  2538.62632,
#  2585.955652,
#  5096.673223,
#  10083.48688,
#  4943.386117,
#  6516.214888,
#  8838.085637,
#  3810.238281,
#  6334.466403,
#  11665.09779,
#  10972.06778,
#  6006.963446,
#  2656.713092,
#  2359.423599,
#  12036.62051,
#  8467.387317,
#  9392.557553,
#  5227.230377,
#  2693.75925,
#  2227.072755,
#  2326.864833,
#  16794.31422,
#  5016.827946,
#  7757.924239,
#  8609.158215,
#  5275.056933,
#  5746.32619,
#  2705.987629,
#  6186.265217,
#  22445.28088,
#  6277.844624,
#  7215.821106,
#  6514.430592,
#  34708.87261,
#  4216.19522,
#  13158.37206,
#  2917.539465,
#  6355.678846,
#  13269.59942,
#  5880.256499,
#  5926.729379,
#  4121.252137,
#  7956.152761,
#  24127.50402,
#  26864.20332,
#  31934.62164,
#  5132.684537,
#  4759.624343,
#  2637.942355,
#  6503.397049,
#  12786.66898,
#  3147.973444,
#  5618.485357,
#  3230.576665,
#  7434.675149,
# ...

# %%
insurance_df['number of open complaints'].replace({'nan':'8028.803803'}, inplace=True)

# %%
insurance_df['number of open complaints'].unique().tolist()
# Out:
# [nan,
#  3479.137523,
#  2502.637401,
#  3265.156348,
#  4455.843406,
#  7704.95848,
#  2750.705045,
#  13024.13012,
#  2538.62632,
#  2585.955652,
#  5096.673223,
#  10083.48688,
#  4943.386117,
#  6516.214888,
#  8838.085637,
#  3810.238281,
#  6334.466403,
#  11665.09779,
#  10972.06778,
#  6006.963446,
#  2656.713092,
#  2359.423599,
#  12036.62051,
#  8467.387317,
#  9392.557553,
#  5227.230377,
#  2693.75925,
#  2227.072755,
#  2326.864833,
#  16794.31422,
#  5016.827946,
#  7757.924239,
#  8609.158215,
#  5275.056933,
#  5746.32619,
#  2705.987629,
#  6186.265217,
#  22445.28088,
#  6277.844624,
#  7215.821106,
#  6514.430592,
#  34708.87261,
#  4216.19522,
#  13158.37206,
#  2917.539465,
#  6355.678846,
#  13269.59942,
#  5880.256499,
#  5926.729379,
#  4121.252137,
#  7956.152761,
#  24127.50402,
#  26864.20332,
#  31934.62164,
#  5132.684537,
#  4759.624343,
#  2637.942355,
#  6503.397049,
#  12786.66898,
#  3147.973444,
#  5618.485357,
#  3230.576665,
#  7434.675149,
# ...

# %%
mean_number_of_open_complaints = np.mean(insurance_df['number of open complaints'])

# %%
insurance_df['number of open complaints'] = insurance_df['number of open complaints'].fillna(mean_number_of_open_complaints)

# %%
insurance_df['number of open complaints'].isna()==True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Name: number of open complaints, Length: 12074, dtype: bool

# %% [markdown]
# Replace the nan in the column 'customer lifetime value'

# %%
mean_customer_lifetime_value = np.mean(insurance_df['customer lifetime value'])

# %%
insurance_df['customer lifetime value'] = insurance_df['customer lifetime value'].fillna(mean_customer_lifetime_value)

# %%
insurance_df['customer lifetime value'].isna()==True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Name: customer lifetime value, Length: 12074, dtype: bool

# %% [markdown]
# #### Bucketing the data

# %% [markdown]
# Replace the names in the column 'State' with the different zones

# %%
insurance_df['state'].replace({'California': 'West Region', 'Oregon':'North West', 'Washington': 'East', 'Arizona':'Central', 'Nevada':'Central'}, inplace=True)

# %%
insurance_df
# Out:
#             state gender             education   income  \
# 0            East    NaN                Master      0.0
# 1         Central      F              Bachelor      0.0
# 2         Central      F              Bachelor  48767.0
# 3     West Region      M              Bachelor      0.0
# 4            East      M  High School or Below  36357.0
# ...           ...    ...                   ...      ...
# 7065  West Region      M              Bachelor  71941.0
# 7066  West Region      F               College  21604.0
# 7067  West Region      M              Bachelor      0.0
# 7068  West Region      M               College  21941.0
# 7069  West Region      M               College      0.0
#
#       customer lifetime value  vehicle class  monthly premium auto  \
# 0                 8028.803803  Four-Door Car                1000.0
# 1                 8028.803803  Four-Door Car                  94.0
# 2                 8028.803803   Two-Door Car                 108.0
# ...

# %% [markdown]
# Standardizing the data - Use string functions to standardize the text data (lower case)

# %%
categorical_columns_df = insurance_df.select_dtypes('object')

# %%
categorical_columns_df
# Out:
#             state gender             education  vehicle class     policy type
# 0            East    NaN                Master  Four-Door Car   Personal Auto
# 1         Central      F              Bachelor  Four-Door Car   Personal Auto
# 2         Central      F              Bachelor   Two-Door Car   Personal Auto
# 3     West Region      M              Bachelor            SUV  Corporate Auto
# 4            East      M  High School or Below  Four-Door Car   Personal Auto
# ...           ...    ...                   ...            ...             ...
# 7065  West Region      M              Bachelor  Four-Door Car   Personal Auto
# 7066  West Region      F               College  Four-Door Car  Corporate Auto
# 7067  West Region      M              Bachelor  Four-Door Car  Corporate Auto
# 7068  West Region      M               College  Four-Door Car   Personal Auto
# 7069  West Region      M               College   Two-Door Car  Corporate Auto
#
# [12074 rows x 5 columns]

# %%
categorical_columns_df.apply(lambda x: x.astype(str).str.lower())
# Out:
#             state gender             education  vehicle class     policy type
# 0            east    nan                master  four-door car   personal auto
# 1         central      f              bachelor  four-door car   personal auto
# 2         central      f              bachelor   two-door car   personal auto
# 3     west region      m              bachelor            suv  corporate auto
# 4            east      m  high school or below  four-door car   personal auto
# ...           ...    ...                   ...            ...             ...
# 7065  west region      m              bachelor  four-door car   personal auto
# 7066  west region      f               college  four-door car  corporate auto
# 7067  west region      m              bachelor  four-door car  corporate auto
# 7068  west region      m               college  four-door car   personal auto
# 7069  west region      m               college   two-door car  corporate auto
#
# [12074 rows x 5 columns]

# %%
#def lower_case_column_names(insurance_df):
    #insurance_df.columns=[i. lower() for i in insurance_df.columns]
    #return insurance_df

# %%
#def lower_case(object_columns):
    #object_columns = [i.lower() for i in object_columns]
    #return insurance_df

# %%
#lower_case(object_columns)
# Out:
#             state gender             education   income  \
# 0            East    NaN                Master      0.0
# 1         Central      F              Bachelor      0.0
# 2         Central      F              Bachelor  48767.0
# 3     West Region      M              Bachelor      0.0
# 4            East      M  High School or Below  36357.0
# ...           ...    ...                   ...      ...
# 7065  West Region      M              Bachelor  71941.0
# 7066  West Region      F               College  21604.0
# 7067  West Region      M              Bachelor      0.0
# 7068  West Region      M               College  21941.0
# 7069  West Region      M               College      0.0
#
#       customer lifetime value  vehicle class  monthly premium auto  \
# 0                 8028.803803  Four-Door Car                1000.0
# 1                 8028.803803  Four-Door Car                  94.0
# 2                 8028.803803   Two-Door Car                 108.0
# ...

# %% [markdown]
# #### Activity 3

# %% [markdown]
# Numerical columns:

# %%
numerical_columns_df = insurance_df.select_dtypes(include=np.number)

# %% [markdown]
# or: dataframe.get_numeric_data()

# %%
numerical_columns_df
# Out:
#        income  customer lifetime value  monthly premium auto  \
# 0         0.0              8028.803803                1000.0
# 1         0.0              8028.803803                  94.0
# 2     48767.0              8028.803803                 108.0
# 3         0.0              8028.803803                 106.0
# 4     36357.0              8028.803803                  68.0
# ...       ...                      ...                   ...
# 7065  71941.0             23405.987980                  73.0
# 7066  21604.0              3096.511217                  79.0
# 7067      0.0              8163.890428                  85.0
# 7068  21941.0              7524.442436                  96.0
# 7069      0.0              2611.836866                  77.0
#
#       number of open complaints  total claim amount
# 0                   8028.803803            2.704934
# 1                   8028.803803         1131.464935
# 2                   8028.803803          566.472247
# ...

# %% [markdown]
# Categorical columns:

# %%
categorical_columns_df
# Out:
#             state gender             education  vehicle class     policy type
# 0            East    NaN                Master  Four-Door Car   Personal Auto
# 1         Central      F              Bachelor  Four-Door Car   Personal Auto
# 2         Central      F              Bachelor   Two-Door Car   Personal Auto
# 3     West Region      M              Bachelor            SUV  Corporate Auto
# 4            East      M  High School or Below  Four-Door Car   Personal Auto
# ...           ...    ...                   ...            ...             ...
# 7065  West Region      M              Bachelor  Four-Door Car   Personal Auto
# 7066  West Region      F               College  Four-Door Car  Corporate Auto
# 7067  West Region      M              Bachelor  Four-Door Car  Corporate Auto
# 7068  West Region      M               College  Four-Door Car   Personal Auto
# 7069  West Region      M               College   Two-Door Car  Corporate Auto
#
# [12074 rows x 5 columns]
