# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
vehicles_df = pd.read_csv("data/vehicles.csv")
vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %%
## Describing the data frame
vehicles_df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
#Use df.info() to explore the data
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
#To count values in a specific column
vehicles_df.Make.value_counts()
# Out:
# Chevrolet                             3643
# Ford                                  2946
# Dodge                                 2360
# GMC                                   2347
# Toyota                                1836
# BMW                                   1677
# Mercedes-Benz                         1284
# Nissan                                1253
# Volkswagen                            1047
# Mitsubishi                             950
# Mazda                                  915
# Audi                                   890
# Porsche                                862
# Honda                                  836
# Jeep                                   829
# Pontiac                                784
# Subaru                                 781
# Volvo                                  717
# Hyundai                                662
# Chrysler                               641
# Buick                                  537
# Mercury                                532
# ...

# %%
#To find the values
vehicles_df.values
# Out:
# array([['AM General', 'DJ Po Vehicle 2WD', 1984, ..., 17,
#         522.7647058823529, 1950],
#        ['AM General', 'FJ8c Post Office', 1984, ..., 13,
#         683.6153846153846, 2550],
#        ['AM General', 'Post Office DJ5 2WD', 1985, ..., 16, 555.4375,
#         2100],
#        ...,
#        ['smart', 'fortwo coupe', 2015, ..., 36, 244.0, 1100],
#        ['smart', 'fortwo coupe', 2016, ..., 36, 246.0, 1100],
#        ['smart', 'fortwo coupe', 2016, ..., 35, 255.0, 1150]],
#       dtype=object)

# %%
#See if there are missing values
missing_values = vehicles_df.isnull()
missing_values.sum()
# Out:
# Make                       0
# Model                      0
# Year                       0
# Engine Displacement        0
# Cylinders                  0
# Transmission               0
# Drivetrain                 0
# Vehicle Class              0
# Fuel Type                  0
# Fuel Barrels/Year          0
# City MPG                   0
# Highway MPG                0
# Combined MPG               0
# CO2 Emission Grams/Mile    0
# Fuel Cost/Year             0
# dtype: int64

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %%
#Replace all brand names that contain the word"Dutton" for simply "Dutton"
vehicles_df.loc[vehicles_df["Make"].str.contains('Dutton') == True, "Make"] = "Dutton"

#Show if it is replaced
vehicles_df["Make"][vehicles_df["Make"].str.contains('Dutton')]

#Clean the other names too
vehicles_df.loc[vehicles_df["Make"].str.contains('BMW') == True, "Make"] = "BMW"
vehicles_df.loc[vehicles_df["Make"].str.contains('Saleen') == True, "Make"] = "Saleen"
vehicles_df.loc[vehicles_df["Make"].str.contains('PAS') == True, "Make"] = "PAS"
vehicles_df.loc[vehicles_df["Make"].str.contains('Panos') == True, "Make"] = "Panoz Auto Development"

#Count the values of the column Make to see if it was replaced
print(vehicles_df["Make"].value_counts())
# Out:
# 11012    Dutton
# 30164    Dutton
# 31754    Dutton
# Name: Make, dtype: object
# Chevrolet                           3643
# Ford                                2946
# Dodge                               2360
# GMC                                 2347
# Toyota                              1836
# BMW                                 1680
# Mercedes-Benz                       1284
# Nissan                              1253
# Volkswagen                          1047
# Mitsubishi                           950
# Mazda                                915
# Audi                                 890
# Porsche                              862
# Honda                                836
# Jeep                                 829
# Pontiac                              784
# Subaru                               781
# Volvo                                717
# Hyundai                              662
# Chrysler                             641
# Buick                                537
# ...

# %%
#Convert CO2 Emissions from Grams/Mile to Grams/Km
print(vehicles_df.loc[:, "CO2 Emission Grams/Mile"])
vehicles_df.loc[:,"CO2 Emission Grams/Mile"] = vehicles_df.loc[:,"CO2 Emission Grams/Mile"] / 1.60934
# Out:
# 0        1.076180
# 1        1.407312
# 2        1.143441
# 3        1.407312
# 4        1.143441
#            ...
# 35947    0.502306
# 35948    0.500247
# 35949    0.502306
# 35950    0.506423
# 35951    0.524951
# Name: CO2 Emission Grams/Mile, Length: 35952, dtype: float64

# %%
#Rename the column 'CO2 Emission Grams/Mile' to 'CO2 Emission Grams/Km'
vehicles_df.rename(columns = {"CO2 Emission Grams/Mile":"CO2 Emission Grams/Km"}, inplace = True)
print(vehicles_df.info)
# Out:
# <bound method DataFrame.info of                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
#The column was renamed
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Make                   35952 non-null  object
#  1   Model                  35952 non-null  object
#  2   Year                   35952 non-null  int64
#  3   Engine Displacement    35952 non-null  float64
#  4   Cylinders              35952 non-null  float64
#  5   Transmission           35952 non-null  object
#  6   Drivetrain             35952 non-null  object
#  7   Vehicle Class          35952 non-null  object
#  8   Fuel Type              35952 non-null  object
#  9   Fuel Barrels/Year      35952 non-null  float64
#  10  City MPG               35952 non-null  float64
#  11  Highway MPG            35952 non-null  float64
#  12  Combined MPG           35952 non-null  float64
#  13  CO2 Emission Grams/Km  35952 non-null  float64
# ...

# %%
#Create a binary column that solely indicates if the transmission of a car is automatic or manual. 
#Use pandas.Series.str.startswith

# %%
#Converting MPG columns to km_per_liter
vehicles_df.loc[:,"City MPG"] = vehicles_df.loc[:,"City MPG"] * (1.60934/3.78541)

# Same with Higway MPG, Combined MPG

vehicles_df.loc[:,"Highway MPG"] = vehicles_df.loc[:,"Highway MPG"] * (1.60934/3.78541)

vehicles_df.loc[:,"Combined MPG"] = vehicles_df.loc[:,"Combined MPG"] * (1.60934/3.78541)

print(vehicles_df["City MPG"].value_counts())
# Out:
# 0.208337    4158
# 0.236115    3690
# 0.222226    3577
# 0.250004    3547
# 0.194448    2760
# 0.263893    2629
# 0.291671    1993
# 0.180558    1959
# 0.277782    1905
# 0.166669    1512
# 0.152780    1422
# 0.305560    1400
# 0.319450    1174
# 0.333339     702
# 0.347228     603
# 0.138891     516
# 0.361117     485
# 0.375006     396
# 0.388895     298
# 0.125002     194
# 0.402784     157
# 0.416673     151
# 0.430562     151
# 0.111113      84
# 0.444452      58
# 0.458341      53
# 0.486119      44
# 0.472230      44
# 0.555564      38
# 0.527786      31
# 0.500008      31
# 0.513897      30
# 0.597232      23
# 0.569453      21
# 0.097224      20
# 0.541675      17
# 0.611121      16
# 0.583343      14
# 0.666677      12
# 0.708345      10
# 0.625010       6
# 0.736123       5
# 0.083335       5
# 0.680566       3
# 0.750012       2
# 0.805568       2
# 0.694455       2
# 0.652788       2
# Name: City MPG, dtype: int64

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Grams/Mile * Mile/Km -> Grams/Mile * 1 Mile/1.60934Km
#
# $$ \frac{Grams}{Mile} * \frac{Mile}{Km} $$
#
# $$ \frac{Grams}{Mile} * \frac{1 Mile}{1.60934Km}  $$

# %% [markdown]
# convert MPG columns to km_per_liter
#
# MPG = Miles/Gallon -> Km/Liter
#
# 1 Mile = 1.60934 Km
#
# 1 Gallon = 3.78541 Liters
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{Km}{Miles} * \frac{Gallon}{Liters}$$
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{1.60934Km}{ 1Miles} * \frac{1 Gallon}{3.78541 Liters}$$
#
# * ( 1.60934 / 3.78541 )

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
# How many car makers?
vehicles_df["Make"].describe
# Out:
# <bound method NDFrame.describe of 0              AM General
# 1              AM General
# 2              AM General
# 3              AM General
# 4        ASC Incorporated
#                ...
# 35947               smart
# 35948               smart
# 35949               smart
# 35950               smart
# 35951               smart
# Name: Make, Length: 35952, dtype: object>

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
## your Code here

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here
