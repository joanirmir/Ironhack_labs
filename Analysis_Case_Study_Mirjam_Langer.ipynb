# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 50

# %%
def concatinate_data_files():
    file1 = pd.read_csv('data/file1.csv')
    file2 = pd.read_csv('data/file2.csv')
    file3 = pd.read_csv('data/file3.csv')
    return pd.concat([file1,file2,file3.rename(columns = {'State':'ST', 'Gender':'GENDER'}, inplace = True)], axis=0)

# %%
insurance_df = concatinate_data_files()

# %%
insurance_df
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
#       Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0        0.0                1000.0                    1/0/00   Personal Auto
# 1        0.0                  94.0                    1/0/00   Personal Auto
# 2    48767.0                 108.0                    1/0/00   Personal Auto
# 3        0.0                 106.0                    1/0/00  Corporate Auto
# 4    36357.0                  68.0                    1/0/00   Personal Auto
# ..       ...                   ...                       ...             ...
# 991  63513.0                  70.0                    1/0/00   Personal Auto
# 992  58161.0                  68.0                    1/0/00  Corporate Auto
# 993  83640.0                  70.0                    1/0/00  Corporate Auto
# 994      0.0                  96.0                    1/0/00   Personal Auto
# 995      0.0                 111.0                    1/0/00   Personal Auto
#
#      Vehicle Class  Total Claim Amount
# 0    Four-Door Car            2.704934
# 1    Four-Door Car         1131.464935
# 2     Two-Door Car          566.472247
# 3              SUV          529.881344
# 4    Four-Door Car           17.269323
# ..             ...                 ...
# 991  Four-Door Car          185.667213
# 992  Four-Door Car          140.747286
# 993   Two-Door Car          471.050488
# 994   Two-Door Car           28.460568
# 995            SUV          700.349052
#
# [5004 rows x 11 columns]

# %%
#Standarizing header names
# Lower case column names
def lower_case_column_names(insurance_df):
    insurance_df.columns=[i. lower() for i in insurance_df.columns]
    return insurance_df

# %%
insurance_df = lower_case_column_names(insurance_df)

# %%
insurance_df
# Out:
#     customer          st gender             education customer lifetime value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
#       income  monthly premium auto number of open complaints     policy type  \
# 0        0.0                1000.0                    1/0/00   Personal Auto
# 1        0.0                  94.0                    1/0/00   Personal Auto
# 2    48767.0                 108.0                    1/0/00   Personal Auto
# 3        0.0                 106.0                    1/0/00  Corporate Auto
# 4    36357.0                  68.0                    1/0/00   Personal Auto
# ..       ...                   ...                       ...             ...
# 991  63513.0                  70.0                    1/0/00   Personal Auto
# 992  58161.0                  68.0                    1/0/00  Corporate Auto
# 993  83640.0                  70.0                    1/0/00  Corporate Auto
# 994      0.0                  96.0                    1/0/00   Personal Auto
# 995      0.0                 111.0                    1/0/00   Personal Auto
#
#      vehicle class  total claim amount
# 0    Four-Door Car            2.704934
# 1    Four-Door Car         1131.464935
# 2     Two-Door Car          566.472247
# 3              SUV          529.881344
# 4    Four-Door Car           17.269323
# ..             ...                 ...
# 991  Four-Door Car          185.667213
# 992  Four-Door Car          140.747286
# 993   Two-Door Car          471.050488
# 994   Two-Door Car           28.460568
# 995            SUV          700.349052
#
# [5004 rows x 11 columns]

# %%
#Rename columns
def rename_columns(insurance_df):
    insurance_df.rename(columns = {'st':'state'}, inplace = True)
    return insurance_df

# %%
insurance_df = rename_columns(insurance_df)

# %%
insurance_df.head()
# Out:
#         state gender             education   income  customer lifetime value  \
# 0  Washington    NaN                Master      0.0                      NaN
# 1     Arizona      F              Bachelor      0.0                      NaN
# 2      Nevada      F              Bachelor  48767.0                      NaN
# 3  California      M              Bachelor      0.0                      NaN
# 4  Washington      M  High School or Below  36357.0                      NaN
#
#    vehicle class  monthly premium auto     policy type  \
# 0  Four-Door Car                1000.0   Personal Auto
# 1  Four-Door Car                  94.0   Personal Auto
# 2   Two-Door Car                 108.0   Personal Auto
# 3            SUV                 106.0  Corporate Auto
# 4  Four-Door Car                  68.0   Personal Auto
#
#    number of open complaints  total claim amount
# 0                        NaN            2.704934
# 1                        NaN         1131.464935
# 2                        NaN          566.472247
# 3                        NaN          529.881344
# 4                        NaN           17.269323

# %%
#Deleting and rearranging columns
#Deleting the column customer
def drop_columns(insurance_df):
    insurance_df.drop(columns=['customer'], inplace=True)
    return insurance_df

# %%
#Executing the drop_colums function
drop_columns(insurance_df)
# Out:
#           state gender             education customer lifetime value   income  \
# 0    Washington    NaN                Master                     NaN      0.0
# 1       Arizona      F              Bachelor              697953.59%      0.0
# 2        Nevada      F              Bachelor             1288743.17%  48767.0
# 3    California      M              Bachelor              764586.18%      0.0
# 4    Washington      M  High School or Below              536307.65%  36357.0
# ..          ...    ...                   ...                     ...      ...
# 991     Arizona      M                Master              847141.75%  63513.0
# 992     Arizona      F               College              543121.91%  58161.0
# 993      Nevada      F               College              568964.41%  83640.0
# 994  California      F                Master              368672.38%      0.0
# 995  California      M              Bachelor              399258.39%      0.0
#
#      monthly premium auto number of open complaints     policy type  \
# 0                  1000.0                    1/0/00   Personal Auto
# 1                    94.0                    1/0/00   Personal Auto
# 2                   108.0                    1/0/00   Personal Auto
# 3                   106.0                    1/0/00  Corporate Auto
# 4                    68.0                    1/0/00   Personal Auto
# ..                    ...                       ...             ...
# 991                  70.0                    1/0/00   Personal Auto
# 992                  68.0                    1/0/00  Corporate Auto
# 993                  70.0                    1/0/00  Corporate Auto
# 994                  96.0                    1/0/00   Personal Auto
# 995                 111.0                    1/0/00   Personal Auto
#
#      vehicle class  total claim amount
# 0    Four-Door Car            2.704934
# 1    Four-Door Car         1131.464935
# 2     Two-Door Car          566.472247
# 3              SUV          529.881344
# 4    Four-Door Car           17.269323
# ..             ...                 ...
# 991  Four-Door Car          185.667213
# 992  Four-Door Car          140.747286
# 993   Two-Door Car          471.050488
# 994   Two-Door Car           28.460568
# 995            SUV          700.349052
#
# [5004 rows x 10 columns]

# %%
insurance_df
# Out:
#           state gender             education customer lifetime value   income  \
# 0    Washington    NaN                Master                     NaN      0.0
# 1       Arizona      F              Bachelor              697953.59%      0.0
# 2        Nevada      F              Bachelor             1288743.17%  48767.0
# 3    California      M              Bachelor              764586.18%      0.0
# 4    Washington      M  High School or Below              536307.65%  36357.0
# ..          ...    ...                   ...                     ...      ...
# 991     Arizona      M                Master              847141.75%  63513.0
# 992     Arizona      F               College              543121.91%  58161.0
# 993      Nevada      F               College              568964.41%  83640.0
# 994  California      F                Master              368672.38%      0.0
# 995  California      M              Bachelor              399258.39%      0.0
#
#      monthly premium auto number of open complaints     policy type  \
# 0                  1000.0                    1/0/00   Personal Auto
# 1                    94.0                    1/0/00   Personal Auto
# 2                   108.0                    1/0/00   Personal Auto
# 3                   106.0                    1/0/00  Corporate Auto
# 4                    68.0                    1/0/00   Personal Auto
# ..                    ...                       ...             ...
# 991                  70.0                    1/0/00   Personal Auto
# 992                  68.0                    1/0/00  Corporate Auto
# 993                  70.0                    1/0/00  Corporate Auto
# 994                  96.0                    1/0/00   Personal Auto
# 995                 111.0                    1/0/00   Personal Auto
#
#      vehicle class  total claim amount
# 0    Four-Door Car            2.704934
# 1    Four-Door Car         1131.464935
# 2     Two-Door Car          566.472247
# 3              SUV          529.881344
# 4    Four-Door Car           17.269323
# ..             ...                 ...
# 991  Four-Door Car          185.667213
# 992  Four-Door Car          140.747286
# 993   Two-Door Car          471.050488
# 994   Two-Door Car           28.460568
# 995            SUV          700.349052
#
# [5004 rows x 10 columns]

# %%
#Rearanging columns
list(insurance_df.columns)
# Out:
# ['state',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
insurance_df = insurance_df[[
    'state',
    'gender',
    'education',
    'income',
    'customer lifetime value',
    'vehicle class',
    'monthly premium auto',
    'policy type',
    'number of open complaints',
    'total claim amount']]

insurance_df.head()
# Out:
#         state gender             education   income customer lifetime value  \
# 0  Washington    NaN                Master      0.0                     NaN
# 1     Arizona      F              Bachelor      0.0              697953.59%
# 2      Nevada      F              Bachelor  48767.0             1288743.17%
# 3  California      M              Bachelor      0.0              764586.18%
# 4  Washington      M  High School or Below  36357.0              536307.65%
#
#    vehicle class  monthly premium auto     policy type  \
# 0  Four-Door Car                1000.0   Personal Auto
# 1  Four-Door Car                  94.0   Personal Auto
# 2   Two-Door Car                 108.0   Personal Auto
# 3            SUV                 106.0  Corporate Auto
# 4  Four-Door Car                  68.0   Personal Auto
#
#   number of open complaints  total claim amount
# 0                    1/0/00            2.704934
# 1                    1/0/00         1131.464935
# 2                    1/0/00          566.472247
# 3                    1/0/00          529.881344
# 4                    1/0/00           17.269323

# %%
#Check the data types
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5004 entries, 0 to 995
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      2067 non-null   object
#  1   gender                     1945 non-null   object
#  2   education                  2067 non-null   object
#  3   income                     2067 non-null   float64
#  4   customer lifetime value    0 non-null      float64
#  5   vehicle class              2067 non-null   object
#  6   monthly premium auto       2067 non-null   float64
#  7   policy type                2067 non-null   object
#  8   number of open complaints  0 non-null      float64
#  9   total claim amount         2067 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 430.0+ KB

# %%
insurance_df['customer lifetime value'].unique().tolist()
# Out:
# [nan]

# %%
insurance_df['customer lifetime value'] = pd.to_numeric(insurance_df['customer lifetime value'], errors = 'coerce')

# %%
insurance_df
# Out:
#           state gender             education   income  \
# 0    Washington    NaN                Master      0.0
# 1       Arizona      F              Bachelor      0.0
# 2        Nevada      F              Bachelor  48767.0
# 3    California      M              Bachelor      0.0
# 4    Washington      M  High School or Below  36357.0
# ..          ...    ...                   ...      ...
# 991     Arizona      M                Master  63513.0
# 992     Arizona      F               College  58161.0
# 993      Nevada      F               College  83640.0
# 994  California      F                Master      0.0
# 995  California      M              Bachelor      0.0
#
#      customer lifetime value  vehicle class  monthly premium auto  \
# 0                        NaN  Four-Door Car                1000.0
# 1                        NaN  Four-Door Car                  94.0
# 2                        NaN   Two-Door Car                 108.0
# 3                        NaN            SUV                 106.0
# 4                        NaN  Four-Door Car                  68.0
# ..                       ...            ...                   ...
# 991                      NaN  Four-Door Car                  70.0
# 992                      NaN  Four-Door Car                  68.0
# 993                      NaN   Two-Door Car                  70.0
# 994                      NaN   Two-Door Car                  96.0
# 995                      NaN            SUV                 111.0
#
#         policy type  number of open complaints  total claim amount
# 0     Personal Auto                        NaN            2.704934
# 1     Personal Auto                        NaN         1131.464935
# 2     Personal Auto                        NaN          566.472247
# 3    Corporate Auto                        NaN          529.881344
# 4     Personal Auto                        NaN           17.269323
# ..              ...                        ...                 ...
# 991   Personal Auto                        NaN          185.667213
# 992  Corporate Auto                        NaN          140.747286
# 993  Corporate Auto                        NaN          471.050488
# 994   Personal Auto                        NaN           28.460568
# 995   Personal Auto                        NaN          700.349052
#
# [5004 rows x 10 columns]

# %%
insurance_df['customer lifetime value'].dtypes
# Out:
# dtype('float64')

# %%
insurance_df['number of open complaints'].unique().tolist()
# Out:
# [nan]

# %%
#Correcting data types 
insurance_df['number of open complaints'] = pd.to_numeric(insurance_df['number of open complaints'], errors = 'coerce')

# %%
insurance_df['number of open complaints'].dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number of open complaints'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/pp/zj2l4jcx48v20ggrz_hy7wdr0000gn/T/ipykernel_70953/438218119.py in <module>
# ----> 1 insurance_df['number of open complaints'].dtypes
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'number of open complaints'

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5004 entries, 0 to 995
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      2067 non-null   object
#  1   gender                     1945 non-null   object
#  2   education                  2067 non-null   object
#  3   income                     2067 non-null   float64
#  4   customer lifetime value    0 non-null      float64
#  5   vehicle class              2067 non-null   object
#  6   monthly premium auto       2067 non-null   float64
#  7   policy type                2067 non-null   object
#  8   number of open complaints  0 non-null      float64
#  9   total claim amount         2067 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 430.0+ KB

# %%
insurance_df
# Out:
#           state gender             education   income  \
# 0    Washington    NaN                Master      0.0
# 1       Arizona      F              Bachelor      0.0
# 2        Nevada      F              Bachelor  48767.0
# 3    California      M              Bachelor      0.0
# 4    Washington      M  High School or Below  36357.0
# ..          ...    ...                   ...      ...
# 991     Arizona      M                Master  63513.0
# 992     Arizona      F               College  58161.0
# 993      Nevada      F               College  83640.0
# 994  California      F                Master      0.0
# 995  California      M              Bachelor      0.0
#
#      customer lifetime value  vehicle class  monthly premium auto  \
# 0                        NaN  Four-Door Car                1000.0
# 1                        NaN  Four-Door Car                  94.0
# 2                        NaN   Two-Door Car                 108.0
# 3                        NaN            SUV                 106.0
# 4                        NaN  Four-Door Car                  68.0
# ..                       ...            ...                   ...
# 991                      NaN  Four-Door Car                  70.0
# 992                      NaN  Four-Door Car                  68.0
# 993                      NaN   Two-Door Car                  70.0
# 994                      NaN   Two-Door Car                  96.0
# 995                      NaN            SUV                 111.0
#
#         policy type  number of open complaints  total claim amount
# 0     Personal Auto                        NaN            2.704934
# 1     Personal Auto                        NaN         1131.464935
# 2     Personal Auto                        NaN          566.472247
# 3    Corporate Auto                        NaN          529.881344
# 4     Personal Auto                        NaN           17.269323
# ..              ...                        ...                 ...
# 991   Personal Auto                        NaN          185.667213
# 992  Corporate Auto                        NaN          140.747286
# 993  Corporate Auto                        NaN          471.050488
# 994   Personal Auto                        NaN           28.460568
# 995   Personal Auto                        NaN          700.349052
#
# [5004 rows x 10 columns]

# %%
#Filtering data and correcting typos
insurance_df[(insurance_df['gender'] == "M") | (insurance_df['gender'] == "F")]
# Out:
#           state gender             education   income  \
# 1       Arizona      F              Bachelor      0.0
# 2        Nevada      F              Bachelor  48767.0
# 3    California      M              Bachelor      0.0
# 4    Washington      M  High School or Below  36357.0
# 5        Oregon      F              Bachelor  62902.0
# ..          ...    ...                   ...      ...
# 991     Arizona      M                Master  63513.0
# 992     Arizona      F               College  58161.0
# 993      Nevada      F               College  83640.0
# 994  California      F                Master      0.0
# 995  California      M              Bachelor      0.0
#
#      customer lifetime value  vehicle class  monthly premium auto  \
# 1                        NaN  Four-Door Car                  94.0
# 2                        NaN   Two-Door Car                 108.0
# 3                        NaN            SUV                 106.0
# 4                        NaN  Four-Door Car                  68.0
# 5                        NaN   Two-Door Car                  69.0
# ..                       ...            ...                   ...
# 991                      NaN  Four-Door Car                  70.0
# 992                      NaN  Four-Door Car                  68.0
# 993                      NaN   Two-Door Car                  70.0
# 994                      NaN   Two-Door Car                  96.0
# 995                      NaN            SUV                 111.0
#
#         policy type  number of open complaints  total claim amount
# 1     Personal Auto                        NaN         1131.464935
# 2     Personal Auto                        NaN          566.472247
# 3    Corporate Auto                        NaN          529.881344
# 4     Personal Auto                        NaN           17.269323
# 5     Personal Auto                        NaN          159.383042
# ..              ...                        ...                 ...
# 991   Personal Auto                        NaN          185.667213
# 992  Corporate Auto                        NaN          140.747286
# 993  Corporate Auto                        NaN          471.050488
# 994   Personal Auto                        NaN           28.460568
# 995   Personal Auto                        NaN          700.349052
#
# [1858 rows x 10 columns]

# %%
insurance_df.loc[insurance_df['gender'].str.startswith('M'), 'gender'] = 'M'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pp/zj2l4jcx48v20ggrz_hy7wdr0000gn/T/ipykernel_70953/3596759740.py in <module>
# ----> 1 insurance_df.loc[insurance_df['gender'].str.startswith('M'), 'gender'] = 'M'
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     717         else:
#     718             key = com.apply_if_callable(key, self.obj)
# --> 719         indexer = self._get_setitem_indexer(key)
#     720         self._has_valid_setitem_indexer(key)
#     721
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     658         if isinstance(key, tuple):
#     659             with suppress(IndexingError):
# --> 660                 return self._convert_tuple(key, is_setter=True)
#     661
#     662         if isinstance(key, range):
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/indexing.py in _convert_tuple(self, key, is_setter)
#     783             self._validate_key_length(key)
#     784             for i, k in enumerate(key):
# --> 785                 idx = self._convert_to_indexer(k, axis=i, is_setter=is_setter)
#     786                 keyidx.append(idx)
#     787
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, key, axis, is_setter)
#    1250                 key = list(key)
#    1251
# -> 1252             if com.is_bool_indexer(key):
#    1253                 key = check_bool_indexer(labels, key)
#    1254                 (inds,) = key.nonzero()
#
# /Applications/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
insurance_df['gender'].unique().tolist()

# %%
insurance_df.state.unique()

# %%
insurance_df[(insurance_df['state'] == "Washington") | (insurance_df['gender'] == "Arizona")]

# %%
#Removing duplicates
insurance_df.drop_duplicats()
